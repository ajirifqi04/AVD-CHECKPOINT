# %% [markdown]
# #**Analisis Dataset Fast Food Nutrition**

# %% [markdown]
# **NAMA : AJI RIFQI SURYANA**
#
# **NIM : 2509116054**
#
# **Praktikum AVD CHECKPOINT**

# %% [markdown]
# #**Import Library**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #**Import Dataset Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/FastFoodNutritionMenuV2.csv'

# %% [markdown]
# #**Memuat Dataset**

# %%
df = pd.read_csv(path)
df
# Out:
#          Company                                               Item Calories  \
# 0     McDonald’s                                          Hamburger      250
# 1     McDonald’s                                       Cheeseburger      300
# 2     McDonald’s                                Double Cheeseburger      440
# 3     McDonald’s                                           McDouble      390
# 4     McDonald’s                       Quarter Pounder® with Cheese      510
# ...          ...                                                ...      ...
# 1143   Pizza Hut  Hand Tossed Slices Ultimate Cheese Lover’s® Me...      230
# 1144   Pizza Hut  Hand Tossed Slices Ultimate Cheese Lover’s® Large      310
# 1145   Pizza Hut           Hand Tossed Slices Veggie Lover’s® Small      120
# 1146   Pizza Hut          Hand Tossed Slices Veggie Lover’s® Medium      200
# 1147   Pizza Hut           Hand Tossed Slices Veggie Lover’s® Large      260
#
# ...

# %% [markdown]
# ##**Business Understanding**

# %% [markdown]
# ###**Business Objective**

# %% [markdown]
# Dataset ini berisi informasi nutrisi dari berbagai menu makanan yang tersedia di restoran fast food, dengan kolom yang mencakup berbagai jenis informasi nutrisi seperti jumlah kalori, total lemak, kolesterol, natrium, karbohidrat, serat, gula, protein, serta poin Weight Watchers. Setiap baris mewakili satu item menu dari perusahaan tertentu, seperti McDonald’s, yang memberi gambaran tentang komposisi gizi setiap item makanan mereka.
#
# Restoran fast food seringkali dikaitkan dengan makanan yang kurang sehat karena tingginya jumlah kalori, lemak, dan natrium dalam menu mereka. Banyak konsumen yang ingin menjaga pola makan sehat namun sulit untuk membuat keputusan yang tepat di restoran cepat saji, terutama karena sulit untuk membandingkan nilai gizi antara berbagai menu. Selain itu, perusahaan-perusahaan fast food perlu memastikan bahwa mereka menawarkan pilihan menu yang memenuhi standar kesehatan atau dapat disesuaikan dengan preferensi konsumen yang peduli dengan kesehatan.
#
# Tujuannya adalah untuk memberikan wawasan tentang komposisi gizi menu fast food guna membantu perusahaan dalam merancang strategi menu yang lebih sehat, meningkatkan kepuasan pelanggan, dan menarik konsumen yang peduli kesehatan, sekaligus mendukung pengambilan keputusan yang lebih tepat terkait penawaran produk yang memenuhi kebutuhan diet spesifik pelanggan.

# %% [markdown]
# ##**Assess Situation**

# %% [markdown]
# Dataset ini memberikan informasi nutrisi dari berbagai menu makanan cepat saji, namun terdapat beberapa tantangan yang perlu diperhatikan dalam menganalisisnya. Pertama, dataset ini mungkin terbatas pada menu dari restoran tertentu (seperti McDonald’s), sehingga tidak mewakili seluruh variasi menu di industri restoran fast food. Kedua, tidak ada informasi mengenai ukuran porsi, yang bisa mempengaruhi total kalori dan nilai gizi. Selain itu, dataset ini hanya mencakup beberapa aspek gizi penting dan tidak mencakup mikronutrien atau alergi makanan, yang membatasi pemahaman tentang kesehatan makanan tersebut. Keterbatasan lainnya adalah bahwa data ini hanya fokus pada menu makanan, tanpa mempertimbangkan preferensi konsumen, pola makan, atau demografi, yang penting untuk menganalisis kepuasan pelanggan. Terakhir, data yang terbatas pada satu sumber restoran dan potensi variasi dalam resep antar lokasi dapat mengurangi representativitasnya untuk analisis yang lebih luas.

# %% [markdown]
# ##**Analytic Goals Project Plan**

# %% [markdown]
# Tujuan dari analisis ini adalah untuk menganalisis hubungan antara komposisi gizi dan kepuasan pelanggan, dengan fokus pada mengidentifikasi pola antara nilai gizi seperti kalori, lemak, dan protein terhadap rating pelanggan. Selain itu, analisis ini bertujuan untuk mengidentifikasi menu yang lebih sehat dan memberikan rekomendasi untuk pengembangan menu yang lebih sesuai dengan kebutuhan konsumen yang peduli kesehatan.
#
# Langkah pertama adalah memahami dan memeriksa struktur dataset, kemudian membersihkan data dari nilai yang hilang atau tidak konsisten. Selanjutnya, eksplorasi data akan dilakukan untuk menganalisis hubungan antara komposisi gizi dan rating pelanggan. Setelah itu, segmentasi menu berdasarkan kategori gizi dilakukan untuk menemukan pola sehat, dan akhirnya, rekomendasi akan disusun untuk membantu restoran merancang menu yang lebih sehat dan meningkatkan kepuasan pelanggan.

# %% [markdown]
# #**Data Understanding**

# %% [markdown]
# ###**Informasi Lanjutan**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1148 entries, 0 to 1147
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Company               1148 non-null   object
#  1   Item                  1148 non-null   object
#  2   Calories              1147 non-null   object
#  3   Calories from
# Fat     642 non-null    object
#  4   Total Fat
# (g)         1091 non-null   object
#  5   Saturated Fat
# (g)     1091 non-null   object
#  6   Trans Fat
# (g)         1091 non-null   object
#  7   Cholesterol
# (mg)      1147 non-null   object
#  8   Sodium
# (mg)          1147 non-null   object
#  9   Carbs
# (g)             1091 non-null   object
#  10  Fiber
# (g)             1091 non-null   object
#  11  Sugars
# (g)            1147 non-null   object
#  12  Protein
# (g)           1091 non-null   object
#  13  Weight Watchers
# Pnts  887 non-null    object
# dtypes: object(14)
# ...

# %% [markdown]
# 1. Company
# Jumlah baris: 1148
# Deskripsi: Nama perusahaan atau brand makanan.
#
# 2. Item
# Jumlah baris: 1148
# Deskripsi: Nama menu atau produk makanan.
#
# 3. Calories
# Jumlah baris: 1147
# Deskripsi: Jumlah kalori pada setiap menu, terdapat sedikit data kosong.
#
# 4. Calories from Fat
# Jumlah baris: 642
# Deskripsi: Kalori yang berasal dari lemak, banyak data tidak terisi.
#
# 5. Total Fat (g)
# Jumlah baris: 1091
# Deskripsi: Total kandungan lemak dalam gram.
#
# 6. Saturated Fat (g)
# Jumlah baris: 1091
# Deskripsi: Kandungan lemak jenuh dalam gram.
#
# 7. Trans Fat (g)
# Jumlah baris: 1091
# Deskripsi: Kandungan lemak trans dalam gram.
#
# 8. Cholesterol (mg)
# Jumlah baris: 1147
# Deskripsi: Jumlah kolesterol dalam satuan miligram.
#
# 9. Sodium (mg)
# Jumlah baris: 1147
# Deskripsi: Kandungan natrium dalam miligram.
#
# 10. Carbs (g)
# Jumlah baris: 1091
# Deskripsi: Total karbohidrat dalam gram.
#
# 11. Fiber (g)
# Jumlah baris: 1091
# Deskripsi: Kandungan serat dalam gram.
#
# 12. Sugars (g)
# Jumlah baris: 1147
# Deskripsi: Jumlah gula dalam gram.
#
# 13. Protein (g)
# Jumlah baris: 1091
# Deskripsi: Kandungan protein dalam gram.
#
# 14. Weight Watchers Pnts
# Jumlah baris: 887
# Deskripsi: Poin Weight Watchers untuk setiap menu, cukup banyak data kosong.

# %% [markdown]
# ###**Statistik Deskriptif**

# %%
df.describe(include='all')
# Out:
#            Company      Item Calories Calories from\nFat Total Fat\n(g)  \
# count         1148      1148     1147                642           1091
# unique           6      1072      105                 64             73
# top     McDonald’s  29 fl oz        0                  0              0
# freq           329        11       83                175            357
#
#        Saturated Fat\n(g) Trans Fat\n(g) Cholesterol\n(mg) Sodium \n(mg)  \
# count                1091           1091              1147          1147
# unique                 35             11                65           214
# top                     0              0                 0             0
# freq                  383            954               378            54
#
#        Carbs\n(g) Fiber\n(g) Sugars\n(g) Protein\n(g) Weight Watchers\nPnts
# count        1091       1091        1147         1091                   887
# unique        131         17         122           56                   524
# ...

# %% [markdown]
# 1. **Count (Kelengkapan Data)**
#
# Berdasarkan data, total baris adalah 1.148. Maka dapat disimpulkan:
#
# *   Calories hilang 1 data (1148 − 1147)
# *   Calories from Fat hilang 506 data (1148 − 642)
# *   Total Fat, Saturated Fat, Trans Fat, Carbs, Fiber, Protein masing-masing hilang 57 data (1148 − 1091)
# *   Cholesterol, Sodium, Sugars hilang 1 data (1148 − 1147)
# *   Weight Watchers Pnts hilang 261 data (1148 − 887)
#
# Kesimpulan :
# Kolom Calories from Fat dan Weight Watchers Pnts memiliki missing value paling banyak, sementara kolom Company dan Item sudah lengkap.
#
# 2. Variasi Data (Unique, Top, dan Freq)
#
# *  Company memiliki 6 perusahaan, dengan McDonald’s paling dominan (329 data).
# *  Item memiliki 1.072 item unik, menunjukkan variasi menu yang sangat tinggi.
# *  Sebagian besar kolom nutrisi memiliki nilai 0 sebagai nilai yang paling sering muncul, seperti pada Calories, Total Fat, Trans Fat, dan Fiber.
#
# Interpretasi:
# Dominasi nilai 0 menunjukkan banyak menu dengan kandungan nutrisi rendah atau data yang dicatat sebagai nol.
#
# 3. Pola Umum Distribusi Data
#
# Nilai nutrisi cenderung tidak merata karena frekuensi nilai 0 sangat tinggi.
#
# Banyaknya nilai unik pada kolom seperti Sodium, Sugars, dan Calories menunjukkan variasi kandungan nutrisi antar menu cukup besar.
#
# **Kesimpulan Akhir** :
# Dataset nutrisi memiliki variasi data yang tinggi, namun juga mengandung banyak missing value dan nilai nol yang mendominasi, sehingga diperlukan pembersihan data dan konversi tipe data ke numerik sebelum dilakukan analisis statistik lanjutan agar hasilnya lebih akurat.

# %% [markdown]
# ##**Tipe Data Tiap Kolom**

# %%
df.dtypes
# Out:
# Company                  object
# Item                     object
# Calories                 object
# Calories from\nFat       object
# Total Fat\n(g)           object
# Saturated Fat\n(g)       object
# Trans Fat\n(g)           object
# Cholesterol\n(mg)        object
# Sodium \n(mg)            object
# Carbs\n(g)               object
# Fiber\n(g)               object
# Sugars\n(g)              object
# Protein\n(g)             object
# Weight Watchers\nPnts    object
# dtype: object

# %% [markdown]
# Output menunjukkan bahwa semua kolom bertipe object, artinya data masih terbaca sebagai teks. Hal ini biasanya disebabkan oleh adanya satuan, karakter non-angka, atau data tidak konsisten, sehingga perlu pembersihan dan konversi tipe data sebelum analisis agar hasilnya akurat.

# %% [markdown]
# ##**Inconsistent Values**

# %% [markdown]
# 1. Company
#
# Tidak terdapat inkonsistensi nilai.

# %%
print(df['Company'].unique())
# Out:
# ['McDonald’s' 'Burger King' 'Wendy’s' 'KFC' 'Taco Bell' 'Pizza Hut']

# %% [markdown]
# 2. Item
#
# Tidak terdapat inkonsistensi nilai.

# %%
print(df['Item'].unique())
# Out:
# ['Hamburger' 'Cheeseburger' 'Double Cheeseburger' ...
#  'Hand Tossed Slices Veggie Lover’s® Small'
#  'Hand Tossed Slices Veggie Lover’s® Medium'
#  'Hand Tossed Slices Veggie Lover’s® Large']

# %% [markdown]
# 3. Calories
#
# Kolom Calories mengandung nilai tidak konsisten karena angka masih tersimpan sebagai teks, terdapat nilai non-angka seperti nan dan xa8, serta variasi nilai ekstrem, sehingga perlu dibersihkan dan dikonversi ke numerik sebelum analisis.

# %%
print(df['Calories'].unique())
# Out:
# ['250' '300' '440' '390' '510' '740' '540' '460' '790' '750' '770' '380'
#  '360' '500' '620' '400' '340' '270' '330' '260' '800' '410' '430' '230'
#  '15' '0' '190' '280' '470' '50' '60' '660' '170' '320' '140' '370' '220'
#  '90' '20' '210' nan '100' '40' '450' '160' '420' '480' '570' '560' '1090'
#  '1150' '610' '350' '520' '180' '150' '35' '290' '475' '395' '70' '45'
#  '710' '580' '720' '880' '1160' '860' '1110' '680' '830' '550' '110' '310'
#  '120' '240' '130' '200' '80' '900' '980' '1130' '1220' '1190' '700'
#  '1050' '630' '670' '530' '640' '780' '930' '10' '30' '\xa0' '950' '810'
#  '650' '600' '490' '5' '590' '960' '25' '1200' '840']

# %% [markdown]
# 4. Calories from Fat
#
# Kolom Calories from Fat memiliki nilai tidak konsisten karena angka masih tersimpan sebagai teks, terdapat nilai tidak valid seperti nan dan xa0, serta adanya variasi nilai yang tidak seragam, sehingga perlu pembersihan dan konversi ke tipe numerik sebelum analisis.

# %%
print(df['Calories from\nFat'].unique())
# Out:
# ['80' '110' '210' '170' '230' '380' '260' '220' '250' '350' '360' '150'
#  '240' '200' '90' '140' '190' '100' '0' '160' '270' '20' '50' '180' '40'
#  '70' '60' '35' '15' nan '25' '130' '30' '290' '330' '280' '300' '430'
#  '470' '510' '540' '320' '5' '10' '120' '45' '420' '460' '520' '580' '680'
#  '740' '710' '750' '480' '610' '310' '370' '440' '490' '670' '340' '400'
#  '390' '\xa0']

# %% [markdown]
# 5. Total Fat (g)
#
# Kolom Total Fat (g) mengandung nilai tidak konsisten karena angka masih tersimpan sebagai teks, terdapat nilai tidak valid seperti nan dan xa0, serta campuran bilangan bulat dan desimal, sehingga perlu pembersihan dan konversi ke tipe numerik sebelum analisis.

# %%
print(df['Total Fat\n(g)'].unique())
# Out:
# ['9' '12' '23' '19' '26' '42' '29' '24' '28' '39' '40' '18' '16' '22' '17'
#  '10' '15' '21' '25' '11' '0' '30' '2.5' '6' '2' '20' '4.5' '7' '4' '1.5'
#  '8' nan '3' '27' '33' '37' '31' '32' '48' '52' '56' '60' '36' '0.5' '3.5'
#  '1' '13' '14' '5' '46' '51' '58' '64' '75' '82' '79' '84' '54' '68' '34'
#  '41' '49' '74' '38' '45' '44' '\xa0' '62' '72' '65' '35' '98' '53' '47']

# %% [markdown]
# 6. Saturated Fat (g)
#
# Kolom Saturated Fat (g) memiliki nilai tidak konsisten karena angka masih tersimpan sebagai teks, terdapat nilai tidak valid seperti nan dan xa0, serta campuran nilai nol, bilangan bulat, dan desimal, sehingga perlu pembersihan dan konversi ke tipe numerik sebelum analisis.

# %%
print(df['Saturated Fat\n(g)'].unique())
# Out:
# ['3.5' '6' '11' '8' '12' '19' '10' '17' '16' '3' '2' '7' '4.5' '4' '9'
#  '18' '1.5' '2.5' '0' '5' '1' nan '0.5' '14' '15' '13' '20' '5.5 g' '24'
#  '28' '32' '31' '33' '25' '\xa0' '30']

# %% [markdown]
# 7. Trans Fat (g)
#
# Kolom Trans Fat (g) memiliki nilai yang tidak konsisten karena data angka masih berbentuk string, terdapat nilai kosong (NaN), serta adanya karakter tersembunyi seperti \xa0, sehingga perlu dibersihkan dan dikonversi ke tipe numerik agar dapat dianalisis dengan benar.

# %%
print(df['Trans Fat\n(g)'].unique())
# Out:
# ['0.5' '1.5' '1' '2.5' '2' '0' nan '3' '4' '4.5' '3.5' '\xa0']

# %% [markdown]
# 8. Cholesterol (mg)
#
# Kolom Cholesterol (mg) memiliki nilai yang tidak konsisten karena seluruh angka masih berbentuk string, terdapat nilai kosong (NaN), adanya karakter tersembunyi seperti \xa0, serta nilai tidak valid seperti '<5' dan '555' yang tidak sesuai dengan format numerik standar, sehingga perlu dibersihkan dan dikonversi ke tipe data numerik sebelum dilakukan analisis.

# %%
print(df['Cholesterol\n(mg)'].unique())
# Out:
# ['25' '40' '80' '65' '90' '155' '75' '70' '85' '145' '135' '35' '45' '55'
#  '30' '0' '5' '50' '10' '60' nan '20' '260' '285' '235' '250' '300' '240'
#  '265' '555' '575' '115' '410' '15' '100' '125' '175' '195' '255' '280'
#  '105' '210' '95' '110' '160' '170' '225' '215' '220' '150' '355' '390'
#  '380' '\xa0' '205' '120' '245' '275' '290' '270' '420' '<5' '130' '140'
#  '230' '180']

# %% [markdown]
# 9. Sodium (mg)
#
# Kolom Sodium (mg) memiliki nilai yang tidak konsisten karena data angka masih tersimpan dalam bentuk string, terdapat nilai kosong (NaN), adanya karakter tersembunyi seperti \xa0, serta nilai tidak valid seperti '<1' yang bukan format numerik murni, sehingga perlu dibersihkan dan dikonversi ke tipe data numerik agar dapat dianalisis dengan tepat.

# %%
print(df['Sodium \n(mg)'].unique())
# Out:
# ['520' '750' '1150' '920' '1190' '1380' '1040' '720' '960' '2070' '1700'
#  '1170' '640' '830' '980' '820' '990' '1200' '1000' '1160' '1030' '810'
#  '780' '800' '1080' '2020' '1060' '730' '690' '160' '270' '350' '110'
#  '360' '540' '900' '260' '0' '250' '150' '1010' '1680' '140' '210' '970'
#  '300' '890' '840' '180' '10' '60' nan '340' '500' '530' '850' '280'
#  '1270' '1280' '1180' '1290' '1580' '1110' '1360' '1560' '2150' '2260'
#  '1390' '590' '930' '20' '55' '310' '1300' '115' '510' '680' '85' '35'
#  '95' '220' '320' '170' '370' '90' '135' '120' '240' '190' '330' '130'
#  '200' '230' '125' '15' '5' '30' '45' '40' '80' '65' '70' '100' '105' '50'
#  '1340' '1050' '1410' '1120' '1470' '390' '1930' '1310' '1740' '1870'
#  '380' '560' '410' '710' '740' '1140' '1650' '1630' '470' '1570' '570'
#  '1420' '2840' '400' '25' '290' '610' '760' '1260' '1530' '2190' '1550'
#  '1440' '1960' '2230' '1760' '580' '430' '75' '420' '440' '\xa0' '660'
# ...

# %% [markdown]
# 10. Carbs (g)
#
# Kolom Carbs (g) memiliki nilai yang tidak konsisten karena seluruh data angka masih berbentuk string, terdapat nilai kosong (NaN), adanya karakter tersembunyi seperti \xa0, serta nilai tidak valid seperti '<1' yang bukan numerik murni, sehingga perlu dilakukan pembersihan dan konversi ke tipe data numerik sebelum analisis.

# %%
print(df['Carbs\n(g)'].unique())
# Out:
# ['31' '33' '34' '40' '45' '37' '38' '63' '61' '59' '44' '41' '56' '43'
#  '57' '39' '26' '27' '35' '28' '66' '30' '29' '48' '3' '0' '12' '18' '9'
#  '23' '1' '2' '10' '15' '20' '4' nan '11' '8' '36' '42' '46' '51' '111'
#  '116' '60' '62' '24' '49' '54' '105' '89' '32' '21' '22' '94' '119' '147'
#  '76' '102' '134' '203' '64' '53' '92' '144' '73' '97' '128' '194' '88'
#  '138' '193' '72' '96' '58' '86' '83' '16' '69' '13' '55' '19' '50' '68'
#  '7' '14' '52' '17' '25' '6' '47' '78' '77' '75' '110' '95' '65' '71'
#  '118' '121' '98' '103' '113' '\xa0' '70' '133' '124' '81' '155' '145'
#  '148' '146' '5' '87' '100' '122' '109' '117' '115' '82' '84' '99' '79'
#  '67' '108' '234' '106' '101' '104' '270' '<1']

# %% [markdown]
# 11. Fiber (g)
#
# Kolom Fiber (g) menunjukkan nilai yang tidak konsisten karena data angka masih tersimpan dalam bentuk string, terdapat nilai kosong (NaN), adanya karakter tersembunyi seperti \xa0, serta nilai tidak valid seperti '<1' yang bukan format numerik standar, sehingga perlu dibersihkan dan dikonversi ke tipe numerik agar dapat dianalisis dengan benar.

# %%
print(df['Fiber\n(g)'].unique())
# Out:
# ['2' '3' '4' '1' '5' '6' '0' nan '7' '9' '\xa0' '8' '10' '<1' '31' '14'
#  '11' '15']

# %% [markdown]
# 12. Sugars (g)
#
# Kolom Sugars (g) memiliki nilai yang tidak konsisten karena seluruh data angka masih berbentuk string, terdapat nilai kosong (NaN), serta adanya nilai tidak valid seperti '<1', sehingga perlu dilakukan pembersihan dan konversi ke tipe data numerik agar dapat digunakan untuk analisis secara akurat.

# %%
print(df['Sugars\n(g)'].unique())
# Out:
# ['6' '7' '9' '8' '13' '10' '5' '11' '2' '4' '16' '3' '0' '1' '12' '25' nan
#  '15' '17' '14' '32' '18' '20' '21' '45' '44' '48' '97' '73' '77' '98'
#  '121' '63' '84' '111' '168' '59' '43' '79' '100' '124' '64' '82' '103'
#  '145' '54' '72' '96' '22' '30' '39' '58' '29' '40' '86' '28' '56' '83'
#  '94' '31' '46' '27' '41' '69' '36' '49' '53' '34' '51' '37' '55' '42'
#  '50' '47' '33' '35' '26' '38' '57' '71' '88' '70' '87' '24' '101' '85'
#  '99' '\xa0' '105' '138' '102' '133' '93' '65' '81' '118' '155' '61' '76'
#  '110' '146' '60' '75' '109' '143' '23' '80' '122' '115' '92' '113' '90'
#  '114' '67' '78' '228' '62' '106' '68' '52' '264' '112' '<1']

# %% [markdown]
# 13. Protein (g)
#
# Kolom Protein (g) menunjukkan nilai yang tidak konsisten karena data angka masih tersimpan dalam bentuk string, terdapat nilai kosong (NaN), serta adanya karakter tersembunyi seperti \xa0, sehingga perlu dibersihkan dan dikonversi ke tipe data numerik agar dapat dianalisis dengan tepat.

# %%
print(df['Protein\n(g)'].unique())
# Out:
# ['12' '15' '25' '22' '29' '48' '24' '27' '45' '40' '44' '14' '35' '31'
#  '18' '21' '20' '3' '4' '6' '0' '9' '13' '1' '23' '38' '30' '26' '33' '7'
#  '2' nan '5' '11' '17' '28' '36' '8' '19' '10' '16' '32' '52' '67' '71'
#  '61' '64' '56' '39' '\xa0' '59' '49' '34' '43' '41' '42' '47']

# %% [markdown]
# 14. Weight Watchers Pnts
#
# Kolom Weight Watchers Pnts tidak konsisten karena semua nilainya masih terbaca sebagai teks (string), terdapat karakter tersembunyi seperti \xa0, sehingga data tidak bisa langsung dihitung atau dianalisis dan perlu dibersihkan serta diubah ke tipe angka (float) agar dapat digunakan dengan benar.

# %%
print(df['Weight Watchers\nPnts'].unique())
# Out:
# ['247.5' '297' '433' '383' '502' '720' '534' '452' '775' '736' '751'
#  '373.5' '354' '499' '343' '499.5' '440' '607' '361' '528.5' '385' '332.5'
#  '258' '324.5' '249.5' '250.5' '382' '789' '395' '403' '420' '325' '228.5'
#  '378.5' '497.5' '17' '0' '183' '270' '453' '60' '61' '65' '380.5' '628'
#  '174' '68' '71' '304' '142' '236' '353' '138.5' '198' '314.5' '89.5' '21'
#  '58' '232.5' nan '103' '193.5' '43' '175.5' '290' '366' '441' '157.5'
#  '481' '508' '570' '485' '404' '466' '646' '428' '567' '432' '732' '793'
#  '1090' '1151' '601' '358' '526' '212' '41.5' '150.5' '44' '552' '319'
#  '275' '178' '79' '166' '50.5' '323' '377' '43.5' '808' '650' '268' '495'
#  '271.5' '176.5' '163.5' '172' '115' '656' '815' '998' '659' '874' '1317'
#  '490' '381' '648' '981' '479' '639' '845' '1269' '604' '760' '930' '1246'
#  '471' '617' '830' '105.5' '187.5' '122' '226' '334' '139' '190' '396'
#  '138' '189' '266' '393' '152' '204' '444' '86' '121' '181' '21.5' '19'
# ...

# %% [markdown]
# ##**Missing Values**

# %% [markdown]
# Berdasarkan hasil perhitungan, sebagian besar kolom memiliki missing value yang rendah (di bawah 5%), namun kolom Calories from Fat memiliki nilai kosong paling tinggi sebesar 44.08% dan Weight Watchers Pnts sebesar 22.74%, sehingga keduanya perlu penanganan khusus karena dapat mempengaruhi hasil analisis.

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                        Null Ratio in %
# Company                       0.000000
# Item                          0.000000
# Calories                      0.087108
# Calories from\nFat           44.076655
# Total Fat\n(g)                4.965157
# Saturated Fat\n(g)            4.965157
# Trans Fat\n(g)                4.965157
# Cholesterol\n(mg)             0.087108
# Sodium \n(mg)                 0.087108
# Carbs\n(g)                    4.965157
# Fiber\n(g)                    4.965157
# Sugars\n(g)                   0.087108
# Protein\n(g)                  4.965157
# Weight Watchers\nPnts        22.735192

# %% [markdown]
# ##**Duplicated Values**

# %% [markdown]
# Output menunjukkan bahwa terdapat 7 baris data yang duplikat atau double di seluruh kolom, yang berarti ada informasi yang berulang dan perlu dibersihkan untuk memastikan keakuratan analisis.

# %%
df[df.duplicated()]
# Out:
#          Company                                 Item Calories  \
# 385  Burger King                 Chicken Nuggets- 4pc      170
# 386  Burger King                 Chicken Nuggets- 6pc      260
# 387  Burger King                            Hamburger      240
# 388  Burger King                         Cheeseburger      280
# 399  Burger King                      Soft Serve Cone      190
# 437  Burger King              Fat FREE Milk (8 fl oz)       90
# 438  Burger King  1% Low Fat Chocolate Milk (8 fl oz)      160
#
#     Calories from\nFat Total Fat\n(g) Saturated Fat\n(g) Trans Fat\n(g)  \
# 385                100             11                1.5              0
# 386                150             16                2.5              0
# 387                 90             10                3.5            0.5
# 388                120             13                  6            0.5
# 399                 40            4.5                  3              0
# ...

# %% [markdown]
# ##**Outliers Values**

# %% [markdown]
# Dari hasil persentase outlier, hampir semua kolom punya data yang menyimpang dalam jumlah kecil (sekitar 2–6%), tetapi Trans Fat (g) paling banyak memiliki nilai yang terlalu tinggi atau terlalu rendah dibanding data lainnya (10.89%), disusul Cholesterol (mg) (7.32%), sehingga dua kolom ini perlu diperhatikan karena bisa mempengaruhi hasil analisis.

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom               Persentase Outliers
# Calories                       3.658537
# Total Fat\n(g)                 2.700348
# Saturated Fat\n(g)             3.484321
# Trans Fat\n(g)                10.888502
# Cholesterol\n(mg)              7.317073
# Sodium \n(mg)                  3.048780
# Carbs\n(g)                     4.268293
# Fiber\n(g)                     5.923345
# Sugars\n(g)                    4.703833
# Protein\n(g)                   2.874564

# %% [markdown]
# ##**Eksplorasi Data (EDA)**

# %% [markdown]
# ###**Comparison/Perbandingan**

# %% [markdown]
# Pada bagian **Perbandingan** ini, akan terlihat perbandingan nutrisi antar perusahaan fast food. Seperti yang sudah terlihat pada bar chart **Average Calories per Company**, kita bisa membandingkan rata-rata kalori yang ditawarkan oleh setiap perusahaan. Ini membantu kita mengidentifikasi perusahaan mana yang cenderung punya menu dengan kalori lebih tinggi (seperti Burger King) atau lebih rendah (seperti KFC), memberikan gambaran awal untuk pengembangan menu yang lebih sehat atau pilihan bagi konsumen.

# %%
df['Calories'] = pd.to_numeric(df['Calories'], errors='coerce')
df['Calories'] = df['Calories'].fillna(df['Calories'].dropna().median())

calories_per_company = df.groupby('Company')['Calories'].mean().sort_values(ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x=calories_per_company.index, y=calories_per_company.values, palette='viridis', hue=calories_per_company.index, legend=False)
plt.title('Average Calories per Company')
plt.xlabel('Company')
plt.ylabel('Average Calories')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ###**Composition/Komposisi**

# %% [markdown]
# Pada bagian Komposisi ini, hasil analisis bagaimana elemen-elemen dalam dataset terdistribusi atau membentuk keseluruhan. Melalui pie chart **Proporsi Jumlah Item Berdasarkan Perusahaan**, kita dapat melihat dengan jelas porsi item menu yang disediakan oleh setiap perusahaan fast food di dataset ini. Ini menunjukkan bahwa McDonald’s menyumbang porsi terbesar, diikuti oleh KFC, Burger King, Taco Bell, Wendy’s, dan Pizza Hut, memberikan gambaran visual tentang kontribusi masing-masing perusahaan terhadap total item yang tercatat.

# %%
items_by_company = df['Company'].value_counts()

plt.figure(figsize=(10, 8))
items_by_company.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Proporsi Jumlah Item Berdasarkan Perusahaan')
plt.ylabel('')
plt.axis('equal')
plt.show()

# %% [markdown]
# ###**Distribution/Distribusi**

# %% [markdown]
# Pada bagian Distribution/Distribusi ini, hasil analisis sebaran data dari satu variabel. Seperti yang terlihat pada histogram **Distribusi Kalori (Calories)** di bawahnya, sebagian besar item menu memiliki kalori rendah hingga sedang, dengan puncaknya di kisaran 200-400 kalori. Pola ini menunjukkan ada beberapa menu dengan kalori sangat tinggi, tapi jumlahnya tidak sebanyak menu berkalori lebih rendah.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Calories'], bins=20, kde=True)
plt.title('Distribusi Kalori (Calories)')
plt.xlabel('Calories')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# ###**Relationship/Hubungan**

# %% [markdown]
# Pada bagian **Relationship/Hubungan** ini, analisis bertujuan untuk mengidentifikasi bagaimana variabel-variabel dalam dataset saling terkait. Dengan heatmap **Korelasi antara Kalori dan Total Lemak** yang baru saja ditampilkan, terlihat adanya korelasi positif yang sangat kuat (nilai korelasi sekitar 0.96) antara jumlah kalori dan total lemak. Ini mengindikasikan bahwa makanan dengan kandungan lemak yang lebih tinggi cenderung memiliki jumlah kalori yang lebih tinggi pula, sebuah hubungan yang penting untuk memahami profil nutrisi pada menu fast food.

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data=df[['Calories', 'Total Fat\n(g)']].corr(),
            annot=True,
            cmap='viridis',
            fmt='.2f')
plt.title('Korelasi antara Kalori dan Total Lemak')
plt.show()

# %% [markdown]
# ## **Data Preparation**

# %% [markdown]
# ### **Tipe Data**

# %%
df['Calories'] = pd.to_numeric(df['Calories'], errors='coerce')
df['Calories'] = df['Calories'].astype('Int64')

# %%
df['Total Fat\n(g)'] = pd.to_numeric(df['Total Fat\n(g)'], errors='coerce')
df['Total Fat\n(g)'] = df['Total Fat\n(g)'].astype('float64')

# %%
df['Saturated Fat\n(g)'] = pd.to_numeric(df['Saturated Fat\n(g)'], errors='coerce')
df['Saturated Fat\n(g)'] = df['Saturated Fat\n(g)'].astype('float64')

# %%
df['Trans Fat\n(g)'] = pd.to_numeric(df['Trans Fat\n(g)'], errors='coerce')
df['Trans Fat\n(g)'] = df['Trans Fat\n(g)'].astype('float64')

# %%
df['Cholesterol\n(mg)'] = pd.to_numeric(df['Cholesterol\n(mg)'], errors='coerce')
df['Cholesterol\n(mg)'] = df['Cholesterol\n(mg)'].astype('float64')

# %%
df['Sodium \n(mg)'] = pd.to_numeric(df['Sodium \n(mg)'], errors='coerce')
df['Sodium \n(mg)'] = df['Sodium \n(mg)'].astype('float64')

# %%
df['Carbs\n(g)'] = pd.to_numeric(df['Carbs\n(g)'], errors='coerce')
df['Carbs\n(g)'] = df['Carbs\n(g)'].astype('float64')

# %%
df['Fiber\n(g)'] = pd.to_numeric(df['Fiber\n(g)'], errors='coerce')
df['Fiber\n(g)'] = df['Fiber\n(g)'].astype('float64')

# %%
df['Sugars\n(g)'] = pd.to_numeric(df['Sugars\n(g)'], errors='coerce')
df['Sugars\n(g)'] = df['Sugars\n(g)'].astype('float64')

# %%
df['Protein\n(g)'] = pd.to_numeric(df['Protein\n(g)'], errors='coerce')
df['Protein\n(g)'] = df['Protein\n(g)'].astype('float64')

# %%
df.dtypes
# Out:
# Company                   object
# Item                      object
# Calories                   Int64
# Calories from\nFat        object
# Total Fat\n(g)           float64
# Saturated Fat\n(g)       float64
# Trans Fat\n(g)           float64
# Cholesterol\n(mg)        float64
# Sodium \n(mg)            float64
# Carbs\n(g)               float64
# Fiber\n(g)               float64
# Sugars\n(g)              float64
# Protein\n(g)             float64
# Weight Watchers\nPnts     object
# dtype: object

# %% [markdown]
# Awalnya seluruh kolom pada dataset bertipe object, sehingga belum sesuai untuk analisis numerik. Kemudian dilakukan penyesuaian tipe data menggunakan metode konversi numerik pada pandas agar setiap kolom sesuai dengan isi datanya. Kolom Company dan Item tetap bertipe object karena berisi teks, Calories diubah menjadi int64 karena berupa angka bulat, sedangkan kolom gizi lainnya diubah menjadi float64 karena mengandung nilai desimal. Proses ini juga memungkinkan nilai yang tidak valid berubah menjadi NaN. Perubahan tersebut dilakukan agar perhitungan dan analisis data dapat berjalan dengan benar dan lebih akurat.

# %% [markdown]
# ### **Inconsistent Values**

# %% [markdown]
# Berdasarkan hasil pengecekan, tidak ditemukan inconsistent value pada dataset. Seluruh data sudah konsisten dari segi format, penulisan, dan satuan, sehingga tidak diperlukan penanganan khusus terkait inkonsistensi. Proses pembersihan data pada bagian ini tidak dilakukan karena tidak ada perbedaan atau kesalahan penulisan yang perlu diseragamkan. Namun, masih terdapat beberapa missing value yang perlu diperbaiki, dan penanganannya dilakukan pada tahap khusus di bagian missing values.

# %% [markdown]
# ### **Missing Values**

# %%
df['Calories'] = df['Calories'].fillna(df['Calories'].dropna().median())

# %%
df['Total Fat\n(g)'] = df['Total Fat\n(g)'].fillna(df['Total Fat\n(g)'].dropna().median())

# %%
df['Saturated Fat\n(g)'] = df['Saturated Fat\n(g)'].fillna(df['Saturated Fat\n(g)'].dropna().median())

# %%
df['Trans Fat\n(g)'] = df['Trans Fat\n(g)'].fillna(df['Trans Fat\n(g)'].dropna().median())

# %%
df['Cholesterol\n(mg)'] = df['Cholesterol\n(mg)'].fillna(df['Cholesterol\n(mg)'].dropna().median())

# %%
df['Sodium \n(mg)'] = df['Sodium \n(mg)'].fillna(df['Sodium \n(mg)'].dropna().median())

# %%
df['Carbs\n(g)'] = df['Carbs\n(g)'].fillna(df['Carbs\n(g)'].dropna().median())

# %%
df['Fiber\n(g)'] = df['Fiber\n(g)'].fillna(df['Fiber\n(g)'].dropna().median())

# %%
df['Sugars\n(g)'] = df['Sugars\n(g)'].fillna(df['Sugars\n(g)'].dropna().median())

# %%
df['Protein\n(g)'] = df['Protein\n(g)'].fillna(df['Protein\n(g)'].dropna().median())

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                     Null Ratio in %
# Company                         0.0
# Item                            0.0
# Calories                        0.0
# Total Fat\n(g)                  0.0
# Saturated Fat\n(g)              0.0
# Trans Fat\n(g)                  0.0
# Cholesterol\n(mg)               0.0
# Sodium \n(mg)                   0.0
# Carbs\n(g)                      0.0
# Fiber\n(g)                      0.0
# Sugars\n(g)                     0.0
# Protein\n(g)                    0.0
# Kategori Calories               0.0

# %% [markdown]
# Berdasarkan hasil pemeriksaan, ditemukan beberapa missing value pada kolom numerik. Penanganannya dilakukan dengan metode imputasi menggunakan nilai median dari masing-masing kolom, sehingga setiap data yang kosong digantikan dengan nilai tengah dari data yang tersedia. Median dipilih karena lebih tahan terhadap pengaruh nilai ekstrem, sehingga lebih sesuai untuk data kandungan gizi.
#
# Setelah proses pengisian dilakukan, dilakukan pengecekan ulang terhadap persentase nilai kosong dan diperoleh hasil bahwa seluruh kolom memiliki rasio missing value sebesar 0%. Hal ini menunjukkan bahwa data sudah bersih dan siap digunakan untuk analisis selanjutnya.

# %% [markdown]
# ### **Duplicated Values**

# %%
df = df.drop_duplicates()

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Company, Item, Calories, Calories from
# Fat, Total Fat
# (g), Saturated Fat
# (g), Trans Fat
# (g), Cholesterol
# (mg), Sodium
# (mg), Carbs
# (g), Fiber
# (g), Sugars
# (g), Protein
# (g), Weight Watchers
# Pnts]
# Index: []

# %% [markdown]
# Pada tahap pengecekan duplicated values, dilakukan identifikasi terhadap data yang memiliki seluruh nilai kolom yang sama. Setelah dilakukan pemeriksaan, data yang terdeteksi duplikat kemudian dihapus menggunakan metode penghapusan duplikasi agar setiap baris dalam dataset bersifat unik.
#
# Setelah proses penghapusan dilakukan, dilakukan pengecekan kembali dan tidak ditemukan lagi data yang terduplikasi. Langkah ini bertujuan untuk menghindari perhitungan ganda yang dapat memengaruhi hasil analisis serta menjaga kualitas dan keakuratan data.

# %% [markdown]
# ### **Outliers Values**

# %%
columns_to_impute = ["Trans Fat\n(g)", "Trans Fat\n(g)"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom               Persentase Outliers
# Calories                       3.680982
# Total Fat\n(g)                 2.979842
# Saturated Fat\n(g)             3.505697
# Trans Fat\n(g)                 0.000000
# Cholesterol\n(mg)              7.361963
# Sodium \n(mg)                  3.155127
# Carbs\n(g)                     4.995618
# Fiber\n(g)                     5.959684
# Sugars\n(g)                    5.083260
# Protein\n(g)                   3.943909

# %% [markdown]
# Pada tahap penanganan outlier, kolom Trans Fat (g) memiliki persentase outlier paling tinggi dibandingkan kolom nutrisi lainnya, sehingga dilakukan imputasi untuk mengurangi pengaruh nilai ekstrem terhadap hasil analisis. Imputasi ini bertujuan agar distribusi data menjadi lebih stabil dan tidak menimbulkan bias pada perhitungan statistik.
#
# Sementara itu, kolom lain seperti Calories, Total Fat, Sodium, Carbs, Sugars, dan Protein tidak diimputasi karena persentase outliernya relatif kecil dan masih dianggap wajar dalam konteks data makanan cepat saji. Nilai ekstrem pada kolom tersebut dinilai sebagai variasi alami data, bukan kesalahan, sehingga tetap dipertahankan agar karakteristik asli dataset tidak berubah.

# %% [markdown]
# ### **Data Construct**

# %%
def kategori_calories(Calories):
    if Calories < 300:
        return 'Rendah'
    elif Calories <= 600:
        return 'Sedang'
    else:
        return 'Tinggi'

df['Kategori Calories'] = df['Calories'].apply(kategori_calories)
# Out:
# /tmp/ipykernel_172/1274132285.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kategori Calories'] = df['Calories'].apply(kategori_calories)

# %% [markdown]
# Saya membuat kategori calories supaya angka kalori yang awalnya berupa angka biasa bisa dikelompokkan menjadi rendah, sedang, dan tinggi, sehingga lebih gampang dibaca, dibandingkan, dan membantu melihat mana menu yang kalorinya besar tanpa harus melihat angka satu per satu.

# %% [markdown]
# ### **Data Reduction**

# %%
df = df.drop('Calories from\nFat', axis=1)

# %% [markdown]
# Kolom Calories from Fat dihapus karena nilainya merupakan turunan dari Total Fat dan Calories, sehingga hanya menyebabkan pengulangan informasi dan tidak memberikan tambahan makna dalam analisis.

# %%
df = df.drop('Weight Watchers\nPnts', axis=1)

# %% [markdown]
# Kolom Weight Watchers Pnts dihapus karena berkaitan dengan sistem penilaian diet tertentu dan tidak secara langsung merepresentasikan kandungan gizi, sehingga kurang sesuai dengan tujuan analisis yang berfokus pada komposisi nutrisi.

# %% [markdown]
# ## **Visualisasi**

# %% [markdown]
# ### **Bar Chart**

# %%
perbandingan_daurulang = df.groupby('Company')['Calories'].sum().sort_values(ascending=False).head(5)

plt.figure(figsize=(10, 6)) # Ukuran
plt.bar(perbandingan_daurulang.index, perbandingan_daurulang.values, color='pink') # color warna
plt.xlabel('Company') # keterangan X label
plt.ylabel('Calories') # keterangan y label
plt.title('Perbandingan Rata-Rata Jumlah Kalori Pada Setiap Company') # Judul
plt.xticks(rotation=0, ha='center') # rotasi teks
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan bar chart yang menampilkan rata-rata kandungan kalori pada menu dari setiap perusahaan fast food, terlihat bahwa terdapat perbedaan jumlah kalori antar perusahaan. Beberapa perusahaan memiliki rata-rata kalori yang lebih tinggi dibandingkan yang lain, yang menunjukkan bahwa menu yang ditawarkan cenderung memiliki kandungan energi yang lebih besar. Hal ini mengindikasikan bahwa komposisi gizi pada menu fast food dapat berbeda tergantung pada perusahaan dan jenis menu yang disediakan.
#
# Perusahaan restoran fast food dapat mempertimbangkan untuk mengembangkan variasi menu dengan kandungan kalori yang lebih rendah guna memenuhi kebutuhan konsumen yang lebih peduli terhadap kesehatan. Selain itu, perusahaan juga dapat menyediakan informasi nilai gizi yang lebih jelas pada setiap menu, sehingga membantu konsumen dalam memilih makanan yang lebih sesuai dengan kebutuhan diet mereka. Dengan demikian, perusahaan dapat meningkatkan kepuasan pelanggan sekaligus menarik konsumen yang lebih memperhatikan aspek kesehatan dalam memilih makanan.

# %% [markdown]
# ### **Pie Chart**

# %%
data_company = df.groupby('Company')['Item'].count()

plt.figure(figsize=(6,6))
plt.pie(data_company, labels=data_company.index, autopct='%1.1f%%')
plt.title('Proporsi Jumlah Menu Berdasarkan Perusahaan')
plt.show()

# %% [markdown]
# Pie chart menunjukkan bahwa setiap perusahaan fast food memiliki proporsi jumlah menu yang berbeda dalam dataset. Beberapa perusahaan memiliki persentase menu yang lebih besar dibandingkan perusahaan lain, yang menandakan bahwa perusahaan tersebut menyediakan variasi menu yang lebih banyak. Perbedaan proporsi ini menggambarkan adanya perbedaan strategi dalam penyediaan pilihan menu kepada konsumen.
#
# Perusahaan fast food dapat mempertimbangkan untuk menambah variasi menu agar mampu bersaing dengan perusahaan lain yang memiliki pilihan menu lebih banyak. Selain itu, perusahaan juga dapat mengembangkan menu dengan komposisi gizi yang lebih seimbang, sehingga tidak hanya meningkatkan jumlah pilihan makanan tetapi juga memberikan alternatif menu yang lebih sehat bagi konsumen. Upaya tersebut dapat membantu meningkatkan daya tarik produk serta memenuhi kebutuhan konsumen yang semakin peduli terhadap kesehatan.

# %% [markdown]
# ### **Line Chart**

# %%
# Line Chart (Matplotlib)

# Group by Company
VARIABEL1 = df.groupby('Company').size()

plt.figure(figsize=(20, 6)) # Ukuran figure
plt.plot(VARIABEL1.index, VARIABEL1.values, marker='o', color='red')
plt.title('Jumlah Menu Berdasarkan Perusahaan', fontsize=16) # Judul
plt.xlabel('Company', fontsize=12) # X Keterangan
plt.ylabel('Jumlah Menu', fontsize=12) # Y Keterangan
plt.grid(True)
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# Line chart menunjukkan jumlah menu yang dimiliki oleh masing-masing perusahaan fast food. Terlihat adanya perbedaan jumlah menu antar perusahaan, di mana beberapa perusahaan memiliki jumlah menu lebih banyak dibandingkan perusahaan lainnya. Perbedaan ini menggambarkan variasi strategi perusahaan dalam menyediakan pilihan makanan kepada konsumen.
#
# Perusahaan dapat mengevaluasi variasi menu yang ditawarkan untuk menyesuaikan dengan kebutuhan dan preferensi konsumen. Penambahan menu baru atau inovasi produk dapat dilakukan untuk meningkatkan daya tarik serta memperluas pilihan bagi pelanggan. Selain itu, pengembangan menu yang lebih sehat juga dapat menjadi strategi untuk menarik konsumen yang semakin memperhatikan aspek kesehatan dalam memilih makanan.

# %% [markdown]
# ### **Histogram**

# %%
# Histogram (Matplotlib): Distribusi Kalori
plt.figure(figsize=(8, 5))
plt.hist(df['Calories'], bins=20, color='blue', edgecolor='black')
plt.title('Distribusi Kalori Pada Menu Fast Food')
plt.xlabel('Calories')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Histogram menunjukkan sebaran jumlah kalori pada berbagai menu fast food. Terlihat bahwa sebagian besar menu berada pada rentang kalori tertentu, sementara hanya beberapa menu yang memiliki kalori sangat tinggi. Pola ini menggambarkan bahwa mayoritas menu memiliki kandungan kalori pada tingkat sedang, namun tetap terdapat beberapa menu dengan kalori tinggi yang berpotensi memberikan asupan energi lebih besar bagi konsumen.
#
# Perusahaan dapat mempertimbangkan untuk menyediakan lebih banyak pilihan menu dengan kandungan kalori yang lebih rendah guna mendukung pola makan yang lebih sehat. Selain itu, penyediaan informasi nilai kalori pada setiap menu dapat membantu konsumen dalam memilih makanan yang sesuai dengan kebutuhan nutrisi mereka. Langkah ini dapat meningkatkan kesadaran konsumen terhadap kandungan gizi makanan sekaligus mendukung gaya hidup yang lebih sehat.

# %% [markdown]
# ### **BoxPlot**

# %%
# Boxplot (Seaborn): Kalori berdasarkan Top 5 Perusahaan

# Identifikasi 5 perusahaan teratas berdasarkan jumlah menu
top5company = df['Company'].value_counts().head(5).index

# Filter DataFrame untuk hanya menyertakan 5 perusahaan teratas
df_top5_company = df[df['Company'].isin(top5company)]

plt.figure(figsize=(12, 7)) # Ukuran figure
sns.boxplot(x='Company', y='Calories', data=df_top5_company, palette='viridis', order=top5company, hue='Company', legend=False)

plt.title('Distribusi Kalori pada Top 5 Perusahaan Fast Food', fontsize=16) # Judul
plt.xlabel('Perusahaan', fontsize=12) # X Keterangan
plt.ylabel('Calories', fontsize=12) # Y Keterangan
plt.xticks(rotation=0, ha='center')
plt.tight_layout()
plt.show()

# %% [markdown]
# Boxplot menunjukkan distribusi kandungan kalori pada menu dari lima perusahaan fast food dengan jumlah menu terbanyak. Terlihat adanya perbedaan median serta rentang distribusi kalori antar perusahaan. Beberapa perusahaan memiliki variasi kalori yang lebih luas, yang menandakan bahwa menu yang ditawarkan memiliki perbedaan kandungan kalori yang cukup besar. Selain itu, terdapat beberapa nilai ekstrem yang menunjukkan adanya menu dengan kalori jauh lebih tinggi dibandingkan menu lainnya.
#
# Perusahaan dapat mengevaluasi komposisi nutrisi pada menu yang memiliki kalori sangat tinggi untuk menjaga keseimbangan nilai gizi yang ditawarkan kepada konsumen. Pengembangan menu dengan kalori yang lebih seimbang juga dapat dilakukan agar konsumen memiliki lebih banyak pilihan makanan yang sesuai dengan kebutuhan kesehatan. Selain itu, variasi menu dengan tingkat kalori yang berbeda dapat membantu memenuhi preferensi konsumen yang beragam.

# %% [markdown]
# ### **Scatter Plot**

# %%
plt.figure(figsize=(12,7)) # Ukuran figure
sns.scatterplot(x='Total Fat\n(g)', y='Calories', data=df, hue='Company', palette='viridis')
plt.title('Hubungan Total Fat dan Kalori pada Menu Fast Food', fontsize=16) # Judul
plt.xlabel('Total Fat\n(g)', fontsize=12) # X Keterangan
plt.ylabel('Calories', fontsize=12) # Y Keterangan
plt.tight_layout()
plt.show()

# %% [markdown]
# Scatter plot menunjukkan hubungan antara kandungan Total Fat dan Calories pada menu fast food. Terlihat adanya kecenderungan bahwa menu dengan kandungan lemak yang lebih tinggi juga memiliki jumlah kalori yang lebih besar. Titik-titik pada grafik memperlihatkan penyebaran data dari berbagai perusahaan, yang menunjukkan bahwa kandungan lemak merupakan salah satu faktor yang berkontribusi terhadap tingginya jumlah kalori pada makanan fast food.
#
# Perusahaan dapat memperhatikan komposisi lemak dalam setiap menu untuk menjaga keseimbangan nilai gizi yang ditawarkan. Pengembangan menu dengan kandungan lemak yang lebih rendah dapat menjadi alternatif bagi konsumen yang ingin mengontrol asupan kalori. Selain itu, penyajian informasi nutrisi yang jelas pada setiap menu juga dapat membantu konsumen dalam membuat pilihan makanan yang lebih sehat.

# %% [markdown]
# ### **Bubble Chart**

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='Total Fat\n(g)', y='Calories', size='Sodium \n(mg)', hue='Company', data=df, sizes=(50, 1000), alpha=0.7, palette='viridis')
plt.title('Hubungan Total Fat, Calories, dan Sodium pada Menu Fast Food)', fontsize=16)
plt.xlabel('Total Fat\n(g)', fontsize=12)
plt.ylabel('Calories', fontsize=12)
plt.grid(True)
plt.legend(title='Company', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# Visualisasi bubble chart menunjukkan bahwa semakin tinggi kandungan total fat pada menu fast food, maka jumlah calories juga cenderung meningkat, yang menunjukkan adanya hubungan positif antara lemak dan kalori pada makanan. Selain itu, ukuran bubble yang merepresentasikan sodium menunjukkan bahwa beberapa menu dengan kalori dan lemak tinggi juga memiliki kandungan sodium yang besar. Perbedaan warna pada grafik juga memperlihatkan bahwa setiap perusahaan memiliki variasi komposisi nutrisi yang berbeda pada menu yang mereka tawarkan.
#
# Perusahaan dapat mempertimbangkan untuk mengembangkan atau memodifikasi menu dengan mengurangi kandungan lemak dan sodium agar menghasilkan pilihan makanan dengan kalori yang lebih rendah dan lebih sehat. Selain itu, perusahaan juga dapat menambahkan variasi menu yang lebih seimbang dari sisi nutrisi serta memberikan informasi nilai gizi yang lebih jelas agar konsumen dapat lebih mudah memilih menu yang sesuai dengan kebutuhan pola makan mereka.

# %% [markdown]
# ### **HeatMap**

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data=df[['Calories','Total Fat\n(g)','Saturated Fat\n(g)','Cholesterol\n(mg)',
           'Sodium \n(mg)','Carbs\n(g)','Fiber\n(g)','Sugars\n(g)','Protein\n(g)']].corr(),
            annot=True,
            cmap='viridis',
            fmt='.2f')
plt.title('Korelasi antara Sales, Profit, Quantity')
plt.show()

# %% [markdown]
# Heatmap menunjukkan tingkat korelasi antara berbagai komponen nutrisi pada menu fast food. Terlihat bahwa beberapa variabel memiliki hubungan yang cukup kuat, seperti kalori dengan total lemak serta kalori dengan lemak jenuh. Hubungan ini menunjukkan bahwa peningkatan kandungan lemak pada menu cenderung diikuti dengan peningkatan jumlah kalori. Sementara itu, beberapa nutrisi lain menunjukkan hubungan yang lebih lemah, yang menandakan bahwa tidak semua komponen nutrisi memiliki keterkaitan yang kuat satu sama lain.
#
# Perusahaan dapat memanfaatkan informasi hubungan antar nutrisi ini untuk mengembangkan menu dengan komposisi gizi yang lebih seimbang. Pengurangan kandungan lemak pada menu tertentu dapat menjadi salah satu langkah untuk menurunkan jumlah kalori tanpa mengurangi variasi menu yang tersedia. Selain itu, pemantauan komposisi nutrisi secara berkala juga dapat membantu perusahaan dalam menjaga kualitas serta kesehatan produk yang ditawarkan kepada konsumen.
